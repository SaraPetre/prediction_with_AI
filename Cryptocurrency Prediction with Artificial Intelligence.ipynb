# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Dropout, LSTM
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error
# Out:
# 2024-04-06 12:38:31.670180: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-06 12:39:09.034293: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = pd.read_csv("12 (2) (Data).csv")
print(data.head(0))
data = data.loc[:,['date','high','low','open','Volume XRP','Volume USDT','close']]
print(data.head(5))
print(data.date)
# Out:
# Empty DataFrame
# Columns: [unix, date, symbol, open, high, low, close, Volume XRP, Volume USDT]
# Index: []
#          date    high     low    open   Volume XRP   Volume USDT   close
# 0  12-27-2021  0.9237  0.9200  0.9200    2384512.0  2.198450e+06  0.9226
# 1  12-26-2021  0.9334  0.9052  0.9252  163438501.0  1.499400e+08  0.9200
# 2  12-25-2021  0.9350  0.8981  0.9114  250074945.0  2.302303e+08  0.9252
# 3  12-24-2021  0.9966  0.8964  0.9941  567234092.0  5.377035e+08  0.9115
# 4  12-23-2021  1.0167  0.9372  0.9538  479436230.0  4.729372e+08  0.9941
# 0       12-27-2021
# 1       12-26-2021
# 2       12-25-2021
# 3       12-24-2021
# 4       12-23-2021
#            ...
# 1329      5-8-2018
# 1330      5-7-2018
# 1331      5-6-2018
# 1332      5-5-2018
# 1333      5-4-2018
# Name: date, Length: 1334, dtype: object

# %%
print(data.columns)
# Out:
# Index(['date', 'high', 'low', 'open', 'Volume XRP', 'Volume USDT', 'close'], dtype='object')

# %%
print(data.head)
# Out:
# <bound method NDFrame.head of             date     high      low     open    Volume XRP   Volume USDT  \
# 0     12-27-2021  0.92370  0.92000  0.92000  2.384512e+06  2.198450e+06
# 1     12-26-2021  0.93340  0.90520  0.92520  1.634385e+08  1.499400e+08
# 2     12-25-2021  0.93500  0.89810  0.91140  2.500749e+08  2.302303e+08
# 3     12-24-2021  0.99660  0.89640  0.99410  5.672341e+08  5.377035e+08
# 4     12-23-2021  1.01670  0.93720  0.95380  4.794362e+08  4.729372e+08
# ...          ...      ...      ...      ...           ...           ...
# 1329    5-8-2018  0.84802  0.79200  0.82490  1.297130e+07  1.057184e+07
# 1330    5-7-2018  0.86886  0.80000  0.86482  1.730349e+07  1.419228e+07
# 1331    5-6-2018  0.91800  0.83774  0.90280  1.600204e+07  1.399714e+07
# 1332    5-5-2018  0.93500  0.88800  0.88980  1.681617e+07  1.528200e+07
# 1333    5-4-2018  1.50000  0.50000  0.50000  2.089021e+07  1.894672e+07
#
#         close
# 0     0.92260
# 1     0.92000
# 2     0.92520
# 3     0.91150
# 4     0.99410
# ...       ...
# 1329  0.80667
# 1330  0.82490
# 1331  0.86483
# 1332  0.90280
# 1333  0.88990
#
# [1334 rows x 7 columns]>

# %%
import pandas as pd

# Read CSV file
data = pd.read_csv("12 (2) (Data).csv")

# Check if "date" is in the columns
if "date" in data.columns:
    print("date is in columns")
else:
    print("date is NOT in columns")

# Set 'date' column as index
data = data.set_index("date")  

# Convert index to datetime with nanosecond unit
data.index = pd.to_datetime(data.index, unit='ns')  

# Print index
print(data.index)
# Out:
# date is in columns
# DatetimeIndex(['2021-12-27', '2021-12-26', '2021-12-25', '2021-12-24',
#                '2021-12-23', '2021-12-22', '2021-12-21', '2021-12-20',
#                '2021-12-19', '2021-12-18',
#                ...
#                '2018-05-13', '2018-05-12', '2018-05-11', '2018-05-10',
#                '2018-05-09', '2018-05-08', '2018-05-07', '2018-05-06',
#                '2018-05-05', '2018-05-04'],
#               dtype='datetime64[ns]', name='date', length=1334, freq=None)

# %%
import pandas as pd
# Read CSV file
data = pd.read_csv("12 (2) (Data).csv")

# Check if "date" is in the columns
if "date" in data.columns:
    print("date is in columns")
else:
    print("date is NOT in columns")
data = data.set_index("date")
data.index = pd.to_datetime(data.index,unit='ns')
print(data.index)
# Out:
# date is in columns
# DatetimeIndex(['2021-12-27', '2021-12-26', '2021-12-25', '2021-12-24',
#                '2021-12-23', '2021-12-22', '2021-12-21', '2021-12-20',
#                '2021-12-19', '2021-12-18',
#                ...
#                '2018-05-13', '2018-05-12', '2018-05-11', '2018-05-10',
#                '2018-05-09', '2018-05-08', '2018-05-07', '2018-05-06',
#                '2018-05-05', '2018-05-04'],
#               dtype='datetime64[ns]', name='date', length=1334, freq=None)

# %%
aim = 'close'

# %%
train_data = data.iloc[200:]
test_data = data.iloc[:200]

def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('XRP/USDT', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16);

# %%
line_plot(train_data[aim], test_data[aim], 'training', 'test', title='')

# %%
def normalise_zero_base(continuous):
    return continuous / continuous.iloc[0] - 1

def normalise_min_max(continuous):
    return (continuous - continuous.min()) / (data.max() - continuous.min())

# %%
def extract_window_data(continuous, window_len=5, zero_base=True):
    window_data = []
    for idx in range(len(continuous) - window_len):
        tmp = continuous[idx: (idx + window_len)].copy()
        if zero_base:
            tmp = normalise_zero_base(tmp)
        window_data.append(tmp.values)
    return np.array(window_data)
def prepare_data(continuous, aim, window_len=10, zero_base=True, test_size=0.2):
    X_train = extract_window_data(train_data, window_len, zero_base)
    X_test = extract_window_data(test_data, window_len, zero_base)
    y_train = train_data[aim][window_len:].values
    y_test = test_data[aim][window_len:].values
    if zero_base:
        y_train = y_train / train_data[aim][:-window_len].values - 1
        y_test = y_test / test_data[aim][:-window_len].values - 1

    return train_data, test_data, X_train, X_test, y_train, y_test
import numpy as np

# %%
from tensorflow.keras import layers

# %%
def build_lstm_model(input_data, output_size, neurons, activ_func='linear',
                     dropout=0.2, loss='mse', optimizer='adam'):
    model = Sequential()
    model.add(LSTM(neurons, input_shape=(input_data.shape[1], input_data.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))

    model.compile(loss=loss, optimizer=optimizer)
    return model
np.random.seed(245)
window_len = 5
test_size = 0.2
zero_base = True
lstm_neurons = 50
epochs = 20
batch_size = 32
loss = 'mse'
dropout = 0.24
optimizer = 'adam'
train_data, test_data, X_train, X_test, y_train, y_test = prepare_data(
    data, aim, window_len=window_len, zero_base=zero_base, test_size=test_size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/computation/expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 21
#      19 dropout = 0.24
#      20 optimizer = 'adam'
# ---> 21 train_data, test_data, X_train, X_test, y_train, y_test = prepare_data(
#      22     data, aim, window_len=window_len, zero_base=zero_base, test_size=test_size)
#
# Cell In[11], line 10, in prepare_data(continuous, aim, window_len, zero_base, test_size)
#       9 def prepare_data(continuous, aim, window_len=10, zero_base=True, test_size=0.2):
# ---> 10     X_train = extract_window_data(train_data, window_len, zero_base)
#      11     X_test = extract_window_data(test_data, window_len, zero_base)
#      12     y_train = train_data[aim][window_len:].values
#
# Cell In[11], line 6, in extract_window_data(continuous, window_len, zero_base)
#       4     tmp = continuous[idx: (idx + window_len)].copy()
#       5     if zero_base:
# ----> 6         tmp = normalise_zero_base(tmp)
#       7     window_data.append(tmp.values)
#       8 return np.array(window_data)
#
# Cell In[10], line 2, in normalise_zero_base(continuous)
#       1 def normalise_zero_base(continuous):
# ----> 2     return continuous / continuous.iloc[0] - 1
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/arraylike.py:126, in OpsMixin.__truediv__(self, other)
#     124 @unpack_zerodim_and_defer("__truediv__")
#     125 def __truediv__(self, other):
# --> 126     return self._arith_method(other, operator.truediv)
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/frame.py:7594, in DataFrame._arith_method(self, other, op)
#    7590 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    7592 self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
# -> 7594 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7595 return self._construct_result(new_data)
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/frame.py:7633, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7627     # TODO: The previous assertion `assert right._indexed_same(self)`
#    7628     #  fails in cases with empty columns reached via
#    7629     #  _frame_arith_method_with_reindex
#    7630
#    7631     # TODO operate_blockwise expects a manager of the same type
#    7632     with np.errstate(all="ignore"):
# -> 7633         bm = self._mgr.operate_blockwise(
#    7634             # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    7635             # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7636             # "ArrayManager"
#    7637             # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    7638             # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7639             # "BlockManager"
#    7640             right._mgr,  # type: ignore[arg-type]
#    7641             array_op,
#    7642         )
#    7643     return self._constructor(bm)
#    7645 elif isinstance(right, Series) and axis == 1:
#    7646     # axis=1 means we want to operate row-by-row
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:1589, in BlockManager.operate_blockwise(self, other, array_op)
#    1585 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1586     """
#    1587     Apply array_op blockwise with another (aligned) BlockManager.
#    1588     """
# -> 1589     return operate_blockwise(self, other, array_op)
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/internals/ops.py:63, in operate_blockwise(left, right, array_op)
#      61 res_blks: list[Block] = []
#      62 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 63     res_values = array_op(lvals, rvals)
#      64     if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      65         res_values = res_values.reshape(1, -1)
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:226, in arithmetic_op(left, right, op)
#     222     _bool_arith_check(op, left, right)
#     224     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     225     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 226     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     228 return res_values
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:172, in _na_arithmetic_op(left, right, op, is_cmp)
#     166 except TypeError:
#     167     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     168         # For object dtype, fallback to a masked operation (only operating
#     169         #  on the non-missing values)
#     170         # Don't do this for comparisons, as that will handle complex numbers
#     171         #  incorrectly, see GH#32047
# --> 172         result = _masked_arith_op(left, right, op)
#     173     else:
#     174         raise
#
# File /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:110, in _masked_arith_op(x, y, op)
#     108     # See GH#5284, GH#5035, GH#19448 for historical reference
#     109     if mask.any():
# --> 110         result[mask] = op(xrav[mask], yrav[mask])
#     112 else:
#     113     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
print(X_train.shape)
# Out:
# (1129, 5, 6)

# %%
model = build_lstm_model(
    X_train, output_size=1, neurons=lstm_neurons, dropout=dropout, loss=loss,
    optimizer=optimizer)
modelfit = model.fit(
    X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/20
# /mnt/c/Users/aras/python_iths/iths_2023_sep_dec/aras_venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0365 - val_loss: 0.0084
# Epoch 2/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0115 - val_loss: 0.0043
# Epoch 3/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 4/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - val_loss: 0.0032
# Epoch 5/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - val_loss: 0.0033
# Epoch 6/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - val_loss: 0.0035
# Epoch 7/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 8/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 9/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 10/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 11/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 12/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 13/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 14/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 15/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 16/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 17/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 7.2151e-04
# Epoch 18/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 7.1332e-04
# Epoch 19/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 9.7280e-04
# Epoch 20/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9889e-04 - val_loss: 0.0011

# %%
import matplotlib.pyplot as plt
plt.plot(modelfit.history['loss'],'r',linewidth=2, label='Training loss')
plt.plot(modelfit.history['val_loss'], 'g',linewidth=2, label='Validation loss')
plt.title('LSTM Neural Networks - XRP Model')
plt.xlabel('Epochs numbers')
plt.ylabel('MSE numbers')
plt.show()

# %%
targets = test_data[aim][window_len:]
preds = model.predict(X_test).squeeze()
mean_absolute_error(preds, y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# 0.02006315940457344

# %%
from sklearn.metrics import mean_squared_error
SCORE_MSE=mean_squared_error(preds, y_test)
SCORE_MSE
# Out:
# 0.001254749287351749

# %%
from sklearn.metrics import r2_score
r2_score=r2_score(y_test, preds)
r2_score*100
# Out:
# 90.29051967354029

# %%
preds = test_data[aim].values[:-window_len] * (preds + 1)
preds = pd.Series(index=targets.index, data=preds)
line_plot(targets, preds, 'actual', 'prediction', lw=3)
